# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.DataFrame({'passanger': [61,63,67,69,70,74,76,81,86,91,95,97],'cost': [4.28,4.08,4.42,4.17,4.48,4.30,4.82,4.70,5.11,5.13,5.64,5.56]})

# %%
data
# Out:
#     passanger  cost
# 0          61  4.28
# 1          63  4.08
# 2          67  4.42
# 3          69  4.17
# 4          70  4.48
# 5          74  4.30
# 6          76  4.82
# 7          81  4.70
# 8          86  5.11
# 9          91  5.13
# 10         95  5.64
# 11         97  5.56

# %%
plt.scatter(x = 'passanger', y = 'cost', data = data)

# %%
sns.regplot(x = 'passanger',y = 'cost', data = data)
# Out:
# <AxesSubplot:xlabel='passanger', ylabel='cost'>

# %%
sns.residplot(x='passanger', y='cost', data=data)
# Out:
# <AxesSubplot:xlabel='passanger', ylabel='cost'>

# %% [markdown]
# https://www.statology.org/standardized-residuals-python/
